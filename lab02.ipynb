# %% [markdown]
# # Anaconda
# Anaconda is a _Python distribution_ that is particularly popular for data analysis and scientific computing. Anaconda comes
# with Python 2.7 or Python 3.4 and 100+ cross-platform tested and optimized Python packages.
#
# ### How to install packages
#
# Click ```start``` and select `Anaconda Prompt` in the Anaconda folder. You will see the Anaconda command prompt ready for your command.
#
# Type `cd/`, enter.
#
# #### Checking the version of Anaconda installed in your machine
#
# Type `conda list anaconda$`
#
# #### check the installed packages
#
# Type `conda list`
#
# #### update Anaconda
#
# 1. Update package manager
#     Type `conda update conda`
#
#
# 2. Update the meta-package (i.e. Anaconda)
#     Type `conda update anaconda`
#
#
# 3. Update all installed packages to the latest existing version
#     Type `conda update --all`
#
# You can check  check which version of Python that Anaconda is using, and also
# on which platform that it is running on, along with base paths for environment
# and packages:
# Type `conda info`
#
#
# ### Install a new package using Anaconda prompt
#
# how to install new packages using Anaconda prompt in cases that the installed packages are not enough to solve your problem. We use Git package as an example. Git is one of the popular version control package that we will try it later.
#
# Type `conda update git`
# Type `conda install git`
# Check the version of the Git package by using `git --version` command
#
# ### Play with Spyder
# **Spyder** is a powerful interactive development environment (IDE) for the Python
# with advanced editing, interactive testing, debugging and introspection features.
# The name SPyDER derives from “Scientific Python Development EnviRonment”
# (SPYDER)
#
# At the Anaconda prompt, type `spyder`, and the IDE will show up.
#
# ### Play with the Jupyter notebook
# **Jupyter notebook** is a set of tools for interactively developing and presenting
# Python programming. It makes a working with Python and data easier for
# scientists. It is a web-based application.
#
# The Jupyter notebook combines two components:
# 1. **The web application**: a browser-based which combine text, mathematics,
# computations and their rich media output.
# 2. **Notebook documents**: a representation of all content visible in the web
# application. The Jupyter notebook file extension is `.ipynb`
#
# click `New`, and select `Python3`. You will see the file called `Untitled`.
# The gray rectangle box with `in[]` is called _“cell”_ where we can input
# both **Python code** and **text** using _Mark Down tag_.
#
# Executing code in this cell can be done by either _clicking
# on_ the `run cell` button or hitting `Shift + Return` keys.

# %%
print("Hello world")
# Out:
# Hello world

# %%
# import numpy and matplotlib
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(999)
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2
plt.scatter(x,y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
# Bigger circles

area = (80 * np.random.rand(N))**2
plt.scatter(x,y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
# You have to modify the figure by adding 50 more circles

N = 100
area = (30 * np.random.rand(N))**2
plt.scatter(x,y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")
df # just typing df
# Out:
#         School  Women  Men  Gap
# 0          MIT     94  152   58
# 1     Stanford     96  151   55
# 2      Harvard    112  165   53
# 3       U.Penn     92  141   49
# 4    Princeton     90  137   47
# 5      Chicago     78  118   40
# 6   Georgetown     94  131   37
# 7        Tufts     76  112   36
# 8         Yale     79  114   35
# 9     Columbia     86  119   33
# 10        Duke     93  124   31
# 11   Dartmouth     84  114   30
# 12         NYU     67   94   27
# 13  Notre Dame     73  100   27
# 14     Cornell     80  107   27
# 15    Michigan     62   84   22
# 16       Brown     72   92   20
# 17    Berkeley     71   88   17
# 18       Emory     68   82   14
# 19        UCLA     64   78   14
# 20       SoCal     72   81    9

# %%
print(df)  # print df (there's a difference)
# Out:
#         School  Women  Men  Gap
# 0          MIT     94  152   58
# 1     Stanford     96  151   55
# 2      Harvard    112  165   53
# 3       U.Penn     92  141   49
# 4    Princeton     90  137   47
# 5      Chicago     78  118   40
# 6   Georgetown     94  131   37
# 7        Tufts     76  112   36
# 8         Yale     79  114   35
# 9     Columbia     86  119   33
# 10        Duke     93  124   31
# 11   Dartmouth     84  114   30
# 12         NYU     67   94   27
# 13  Notre Dame     73  100   27
# 14     Cornell     80  107   27
# 15    Michigan     62   84   22
# 16       Brown     72   92   20
# 17    Berkeley     71   88   17
# 18       Emory     68   82   14
# 19        UCLA     64   78   14
# 20       SoCal     72   81    9

# %% [markdown]
# The Jupyter notebook also supports latex’s mathematical formula.

# %%
# %%latex
# \begin{align}
# B’&=-\nabla \times E,\\
# E’&=\nabla \times B - 4\pi j,
# \end{align}
# Out:
# \begin{align}
# B’&=-\nabla \times E,\\
# E’&=\nabla \times B - 4\pi j,
# \end{align}

# %% [markdown]
# ``` Markdown
# # Mahidol University
# ## Faculty of Information and Communication Technology
# #### _We are studying ITCS159_
# #### **Software Lab for Basic Scientific Problem Solving**
#
# - first
# - second
# - third
# ```
# ```markdown
# `Sayyy, Say!!!, Say Ouu, Say Ahh, Say ICT`
# ```

# %% [markdown]
# Output looks like this
#
# # Mahidol University
# ## Faculty of Information and Communication Technology
# #### _We are studying ITCS159_
# #### **Software Lab for Basic Scientific Problem Solving**
#
# - first
# - second
# - third
#
# `Sayyy, Say!!!, Say Ouu, Say Ahh, Say ICT`
